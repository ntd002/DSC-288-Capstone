# %% [markdown]
# # Import CSV

# %%
import pandas as pd
df = pd.read_csv('DSC 288 Processed Reddit Dataset.csv')
print(df)
# Out:
#                                                   Title  \
# 0     Your anger may be caused by a magnesium defici...
# 1     Do you ever get so angry that you wish to kill...
# 2     Does anyone else just avoid people because you...
# 3     Was anyone else “not allowed” to get upset gro...
# 4     I wish people understood that outbursts don't ...
# ...                                                 ...
# 9050                                Anxiety and bruxism
# 9051                                      im giving up
# 9052                                   holding breath?
# 9053                                       I’m curious!
# 9054                           How to break the cycle?
#
#                                                    Text  Score  Topic  \
# 0     I tried absolutely everything to fix my chroni...    741  anger
# 1     I don't know if it's my anger issues talking o...    680  anger
# 2     Lately I’ve been noticing that I take the extr...    478  anger
# 3     I was always scolded for being upset, even at ...    402  anger
# 4     The fact that people think you are being ridic...    370  anger
# ...                                                 ...    ...    ...
# 9050  Does anyone with a long term anxiety disorder ...     10  panic
# 9051  im so tired of this constant anxiety and panic...      9  panic
# 9052  does anyone else catch themselves holding thei...      9  panic
# 9053  I’m curious what age range and genders are of ...     10  panic
# 9054  Anybody ever feels like their losing their min...      9  panic
#
#                                               Title_pro  \
# 0     anger may caused magnesium deficiency neuron l...
# 1                       ever get angry wish kill moment
# 2       anyone else avoid people know theyll make angry
# 3                 anyone else allowed get upset growing
# 4     wish people understood outburst dont happen sm...
# ...                                                 ...
# 9050                                    anxiety bruxism
# 9051                                          im giving
# 9052                                     holding breath
# 9053                                         im curious
# 9054                                        break cycle
#
#                                                Text_pro
# 0     tried absolutely everything fix chronic anger ...
# 1     dont know anger issue talking depressioni dont...
# 2     lately ive noticing take extra step avoid peop...
# 3     always scolded upset even minor thing kid allo...
# 4     fact people think ridiculous really mad small ...
# ...                                                 ...
# 9050  anyone long term anxiety disorder struggle cle...
# 9051  im tired constant anxiety panicky feeling like...
# 9052  anyone else catch holding breath suddenly hype...
# 9053  im curious age range gender people suffering p...
# 9054  anybody ever feel like losing mind im constant...
#
# [9055 rows x 6 columns]

# %%
df['T_T_pro'] = df['Title_pro'] +" "+ df['Text_pro']
print(df['T_T_pro'])
# Out:
# 0       anger may caused magnesium deficiency neuron l...
# 1       ever get angry wish kill moment dont know ange...
# 2       anyone else avoid people know theyll make angr...
# 3       anyone else allowed get upset growing always s...
# 4       wish people understood outburst dont happen sm...
#                               ...
# 9050    anxiety bruxism anyone long term anxiety disor...
# 9051    im giving im tired constant anxiety panicky fe...
# 9052    holding breath anyone else catch holding breat...
# 9053    im curious im curious age range gender people ...
# 9054    break cycle anybody ever feel like losing mind...
# Name: T_T_pro, Length: 9055, dtype: object

# %% [markdown]
# # Feature Extraction/Modeling

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Text_pro'], df['Topic'], test_size=0.2, random_state=2)

# %%
#Create Vectorizer
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
#Train Classifier
clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
#Make Predictions
y_pred = clf.predict(X_test)

#Evaluate Model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6427388183324131

# %%
#Attempt the same but on the title
X_train, X_test, y_train, y_test = train_test_split(df['Title_pro'], df['Topic'], test_size=0.2, random_state=2)
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)
clf = MultinomialNB()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6289342904472667

# %%
#Now on combined title and text
X_train, X_test, y_train, y_test = train_test_split(df['T_T_pro'], df['Topic'], test_size=0.2, random_state=2)
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)
clf = MultinomialNB()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6824958586416344
